# %% [markdown]
# <a href="https://colab.research.google.com/github/thilakraj1708/ThilakRaj_5501/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries (run this first)
# !pip install -q langchain langchain-community langchain-google-genai google-generativeai

# Import required modules
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.schema.messages import HumanMessage, SystemMessage
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
import google.generativeai as genai

# Set your Gemini API key
os.environ["GOOGLE_API_KEY"] ="AIzaSyB8t8uvj5hLWYfuMuo3jyyjfeW-fAaEPZA"

# Initialize the Gemini chat model (using a model you have access to)
llm = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.environ["GOOGLE_API_KEY"]
)

# Define prompt template
prompt = PromptTemplate(
    input_variables=["question"],
    template="You are a helpful chatbot.\nUser: {question}\nAssistant:"
)

# Create LangChain LLM chain
chain = LLMChain(llm=llm, prompt=prompt)

# Function to interact with the bot
def chat_with_bot():
    print("Chatbot is ready! Type 'exit' to stop.\n")
    while True:
        user_input = input("You: ")
        if user_input.lower() in ["exit", "quit"]:
            print("Chatbot:
# Out:
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5054c75be676> in <cell line: 0>()
#       4 # Import required modules
#       5 import os
# ----> 6 from langchain_google_genai import ChatGoogleGenerativeAI
#       7 from langchain.schema.messages import HumanMessage, SystemMessage
#       8 from langchain.chains import LLMChain
#
# ModuleNotFoundError: No module named 'langchain_google_genai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os
from PyPDF2 import PdfReader
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from google.colab import files

# Set your Gemini API key
os.environ["GOOGLE_API_KEY"] = "your-gemini-api-key-here"  # << Replace this!

# Load Gemini 2.5 Pro model
llm = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.environ["GOOGLE_API_KEY"]
)

# Function to extract text from a PDF
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        content = page.extract_text()
        if content:
            text += content + "\n"
    return text

# Prompt for resume analysis
prompt = PromptTemplate(
    input_variables=["resume_text"],
    template="""
You are an expert career coach and recruiter.
Please analyze the resume below and provide feedback.

Resume:
{resume_text}

Provide suggestions for:
1. Formatting
2. Skills and experience clarity
3. Strengths and weaknesses
4. Improvements to make it job-ready

Give feedback in a clear, professional tone.
"""
)

# LangChain pipeline
chain = LLMChain(llm=llm, prompt=prompt)

# Upload and analyze resume
uploaded = files.upload()

for filename in uploaded:
    print(f"\nAnalyzing resume: {filename}")
    resume_text = extract_text_from_pdf(filename)
    response = chain.run(resume_text=resume_text)
    print("\n--- AI Resume Feedback ---\n")
    print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-81e64608c262> in <cell line: 0>()
#       1 import os
# ----> 2 from PyPDF2 import PdfReader
#       3 from langchain_google_genai import ChatGoogleGenerativeAI
#       4 from langchain.prompts import PromptTemplate
#       5 from langchain.chains import LLMChain
#
# ModuleNotFoundError: No module named 'PyPDF2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os
from PyPDF2 import PdfReader
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from google.colab import files

# Set your Gemini API key
os.environ["GOOGLE_API_KEY"] =  "AIzaSyB8t8uvj5hLWYfuMuo3jyyjfeW-fAaEPZA"  # << Replace this!

# Load Gemini 2.5 Pro model
llm = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.environ["GOOGLE_API_KEY"]
)

# Function to extract text from a PDF
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        content = page.extract_text()
        if content:
            text += content + "\n"
    return text

# Prompt for resume analysis
prompt = PromptTemplate(
    input_variables=["resume_text"],
    template="""
You are an expert career coach and recruiter.
Please analyze the resume below and provide feedback.

Resume:
{resume_text}

Provide suggestions for:
1. Formatting
2. Skills and experience clarity
3. Strengths and weaknesses
4. Improvements to make it job-ready

Give feedback in a clear, professional tone.
"""
)

# LangChain pipeline
chain = LLMChain(llm=llm, prompt=prompt)

# Upload and analyze resume
uploaded = files.upload()

for filename in uploaded:
    print(f"\nAnalyzing resume: {filename}")
    resume_text = extract_text_from_pdf(filename)
    response = chain.run(resume_text=resume_text)
    print("\n--- AI Resume Feedback ---\n")
    print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d023129fee25> in <cell line: 0>()
#       1 import os
# ----> 2 from PyPDF2 import PdfReader
#       3 from langchain_google_genai import ChatGoogleGenerativeAI
#       4 from langchain.prompts import PromptTemplate
#       5 from langchain.chains import LLMChain
#
# ModuleNotFoundError: No module named 'PyPDF2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Install all required packages
# !pip install -q langchain langchain-community langchain-google-genai PyPDF2 google-generativeai

import os
from PyPDF2 import PdfReader
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from google.colab import files

# Set your Gemini API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyB8t8uvj5hLWYfuMuo3jyyjfeW-fAaEPZA"  # << Replace this!

# Load Gemini 2.5 Pro model
llm = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.environ["GOOGLE_API_KEY"]
)

# Function to extract text from a PDF
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        content = page.extract_text()
        if content:
            text += content + "\n"
    return text

# Prompt for resume analysis
prompt = PromptTemplate(
    input_variables=["resume_text"],
    template="""
You are an expert career coach and recruiter.
Please analyze the resume below and provide feedback.

Resume:
{resume_text}

Provide suggestions for:
1. Formatting
2. Skills and experience clarity
3. Strengths and weaknesses
4. Improvements to make it job-ready

Give feedback in a clear, professional tone.
"""
)

# LangChain pipeline
chain = LLMChain(llm=llm, prompt=prompt)

# Upload and analyze resume
uploaded = files.upload()

for filename in uploaded:
    print(f"\nAnalyzing resume: {filename}")
    resume_text = extract_text_from_pdf(filename)
    response = chain.run(resume_text=resume_text)
    print("\n--- AI Resume Feedback ---\n")
    print(response)
# Out:
# <ipython-input-6-0e46e604587c>:51: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=llm, prompt=prompt)
#      <input type="file" id="files-7df09b9f-1a18-4b81-8b7d-1a1b4404f73e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7df09b9f-1a18-4b81-8b7d-1a1b4404f73e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
⁸# STEP 1: Install required packages
# !pip install -q langchain langchain-community langchain-google-genai PyPDF2 google-generativeai

# STEP 2: Import and Setup
import os
from PyPDF2 import PdfReader
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from google.colab import files

# Set your Gemini API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyB8t8uvj5hLWYfuMuo3jyyjfeW-fAaEPZA"  # << Replace this!

llm = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.environ["GOOGLE_API_KEY"]
)

# Prompt Template
prompt = PromptTemplate(
    input_variables=["resume_text"],
    template="""
You are an expert career coach and recruiter.
Please analyze the resume below and provide feedback.

Resume:
{resume_text}

Give feedback on:
1. Formatting
2. Skills and experience clarity
3. Strengths and weaknesses
4. Improvements to make it job-ready

Respond in a clear, professional tone.
"""
)

# PDF Extractor
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        content = page.extract_text()
        if content:
            text += content + "\n"
    return text

# STEP 3: Manually set the PDF path
# You can use files.upload() once and manually paste the filename below.
# Or upload via the left-side "Files" tab in Colab and paste the path.
pdf_path = "/content/sample_resume.pdf"  # <- Replace with your actual file name

# Extract and run the chain
resume_text = extract_text_from_pdf(pdf_path)
chain = prompt | llm
response = chain.invoke({"resume_text": resume_text})

print("\n--- AI Resume Feedback ---\n")
print(response.content)
# Out:
#   File "<ipython-input-11-8d811391e865>", line 1
#     ⁸# STEP 1: Install required packages
#     ^
# SyntaxError: invalid character '⁸' (U+2078)
